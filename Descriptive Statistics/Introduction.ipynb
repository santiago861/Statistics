# %%
import pandas as pd # Series, DataFrame, Panel
import numpy as np # Matrix, Vector, arrays
import matplotlib.pyplot as plt # visualizations (static, animated, interactive)
import seaborn as sns # data visualization
import statistics as stat

pd.set_option('display.float_format', lambda x: '%.3f' % x) # it helps us avoid scientific notation
sns.set_style('darkgrid')

# %% [markdown]
# In order to read a file that we have saved on our computer we use pandas. It has the necessary attributes to manage tables.

# %%
# Read file
data = pd.read_csv('/Users/santiago/Downloads/annual-enterprise-survey-2023-financial-year-provisional.csv')
data
# Out:
#           Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 0          NaN                     Level 1                99999
# 1     2023.000                     Level 1                99999
# 2     2023.000                     Level 1                99999
# 3     2023.000                     Level 1                99999
# 4     2023.000                     Level 1                99999
# ...        ...                         ...                  ...
# 17490 2020.000                     Level 1                   MN
# 17491 2020.000                     Level 1                   MN
# 17492 2020.000                     Level 1                   MN
# 17493 2020.000                     Level 1                   MN
# 17494 2020.000                     Level 1                   MN
#
#                                     Industry_name_NZSIOC               Units  \
# 0                                         All industries  Dollars (millions)
# 1                                         All industries  Dollars (millions)
# 2                                         All industries  Dollars (millions)
# 3                                         All industries  Dollars (millions)
# 4                                         All industries  Dollars (millions)
# ...                                                  ...                 ...
# 17490  Professional, Scientific, Technical, Administr...  Dollars (millions)
# 17491  Professional, Scientific, Technical, Administr...  Dollars (millions)
# 17492  Professional, Scientific, Technical, Administr...  Dollars (millions)
# 17493  Professional, Scientific, Technical, Administr...  Dollars (millions)
# 17494  Professional, Scientific, Technical, Administr...  Dollars (millions)
#
#       Variable_code                                    Variable_name  \
# 0               H01                                     Total income
# 1               H04  Sales, government funding, grants and subsidies
# 2               NaN                Interest, dividends and donations
# 3               NaN                             Non-operating income
# 4               H08                                Total expenditure
# ...             ...                                              ...
# 17490           H01                                     Total income
# 17491           H04                      Sales of goods and services
# 17492           H05                Interest, dividends and donations
# 17493           H06         Government funding, grants and subsidies
# 17494           H07                             Non-operating income
#
#            Variable_category   Value  \
# 0      Financial performance  930995
# 1      Financial performance  821630
# 2      Financial performance   84354
# 3      Financial performance   25010
# 4      Financial performance  832964
# ...                      ...     ...
# 17490  Financial performance   59972
# 17491  Financial performance   55029
# 17492  Financial performance    3451
# 17493  Financial performance     457
# 17494  Financial performance    1036
#
#                                   Industry_code_ANZSIC06
# 0      ANZSIC06 divisions A-S (excluding classes K633...
# 1      ANZSIC06 divisions A-S (excluding classes K633...
# 2      ANZSIC06 divisions A-S (excluding classes K633...
# 3      ANZSIC06 divisions A-S (excluding classes K633...
# 4      ANZSIC06 divisions A-S (excluding classes K633...
# ...                                                  ...
# 17490                         ANZSIC06 divisions M and N
# 17491                         ANZSIC06 divisions M and N
# 17492                         ANZSIC06 divisions M and N
# 17493                         ANZSIC06 divisions M and N
# 17494                         ANZSIC06 divisions M and N
#
# [17495 rows x 10 columns]

# %%
# Get the shape of the data we've read
data.shape
# Out:
# (17495, 10)

# %%
data.dtypes
# Out:
# Year                           float64
# Industry_aggregation_NZSIOC     object
# Industry_code_NZSIOC            object
# Industry_name_NZSIOC            object
# Units                           object
# Variable_code                   object
# Variable_name                   object
# Variable_category               object
# Value                           object
# Industry_code_ANZSIC06          object
# dtype: object

# %%
# the method isna() is going to return a same-sized table indicating if the value in the original data is NaN
# the chained sum() method will tell us how many NaN values there are in each category
data.isna().sum()
# Out:
# Year                           10
# Industry_aggregation_NZSIOC     0
# Industry_code_NZSIOC            3
# Industry_name_NZSIOC            0
# Units                           0
# Variable_code                   2
# Variable_name                   0
# Variable_category               0
# Value                           0
# Industry_code_ANZSIC06          0
# dtype: int64

# %% [markdown]
# In the real world, NaN values ​​can be a problem because getting information is difficult. When there are a small number of NaN values, the best practice is to remove them, since **inputting** them can skew the information a bit because we are guessing at the real values. This practice depends on the amount of information we have; removing NaN data when we don't have enough information could take away even more information.
#
# The more data we have, the better

# %%
# dropna return the data without the rows that cointain at least one NaN value
# if we look carefully, the index is not reset, we must reset it to avoid problems with loops
data_without_NaN = data.dropna()
data_without_NaN
# Out:
#           Year Industry_aggregation_NZSIOC Industry_code_NZSIOC  \
# 1     2023.000                     Level 1                99999
# 4     2023.000                     Level 1                99999
# 7     2023.000                     Level 1                99999
# 9     2023.000                     Level 1                99999
# 10    2023.000                     Level 1                99999
# ...        ...                         ...                  ...
# 17490 2020.000                     Level 1                   MN
# 17491 2020.000                     Level 1                   MN
# 17492 2020.000                     Level 1                   MN
# 17493 2020.000                     Level 1                   MN
# 17494 2020.000                     Level 1                   MN
#
#                                     Industry_name_NZSIOC               Units  \
# 1                                         All industries  Dollars (millions)
# 4                                         All industries  Dollars (millions)
# 7                                         All industries  Dollars (millions)
# 9                                         All industries  Dollars (millions)
# 10                                        All industries  Dollars (millions)
# ...                                                  ...                 ...
# 17490  Professional, Scientific, Technical, Administr...  Dollars (millions)
# 17491  Professional, Scientific, Technical, Administr...  Dollars (millions)
# 17492  Professional, Scientific, Technical, Administr...  Dollars (millions)
# 17493  Professional, Scientific, Technical, Administr...  Dollars (millions)
# 17494  Professional, Scientific, Technical, Administr...  Dollars (millions)
#
#       Variable_code                                      Variable_name  \
# 1               H04    Sales, government funding, grants and subsidies
# 4               H08                                  Total expenditure
# 7               H11                                       Depreciation
# 9               H13                           Redundancy and severance
# 10              H14  Salaries and wages to self employed commission...
# ...             ...                                                ...
# 17490           H01                                       Total income
# 17491           H04                        Sales of goods and services
# 17492           H05                  Interest, dividends and donations
# 17493           H06           Government funding, grants and subsidies
# 17494           H07                               Non-operating income
#
#            Variable_category   Value  \
# 1      Financial performance  821630
# 4      Financial performance  832964
# 7      Financial performance   30814
# 9      Financial performance     269
# 10     Financial performance    1639
# ...                      ...     ...
# 17490  Financial performance   59972
# 17491  Financial performance   55029
# 17492  Financial performance    3451
# 17493  Financial performance     457
# 17494  Financial performance    1036
#
#                                   Industry_code_ANZSIC06
# 1      ANZSIC06 divisions A-S (excluding classes K633...
# 4      ANZSIC06 divisions A-S (excluding classes K633...
# 7      ANZSIC06 divisions A-S (excluding classes K633...
# 9      ANZSIC06 divisions A-S (excluding classes K633...
# 10     ANZSIC06 divisions A-S (excluding classes K633...
# ...                                                  ...
# 17490                         ANZSIC06 divisions M and N
# 17491                         ANZSIC06 divisions M and N
# 17492                         ANZSIC06 divisions M and N
# 17493                         ANZSIC06 divisions M and N
# 17494                         ANZSIC06 divisions M and N
#
# [17480 rows x 10 columns]

# %%
plt.figure()
sns.histplot(data_without_NaN['Industry_code_NZSIOC'], color = 'red')
plt.title('Histogram')
plt.xlabel('Industry Code')
plt.ylabel('Frecuency')
plt.show()

# %%
plt.figure(figsize = (3, 6))
sns.boxplot(data_without_NaN['Industry_code_NZSIOC'], color = 'orange')
plt.title('Histogram')
plt.xlabel('Industry Code')
plt.ylabel('Frecuency')
plt.show()

# if we see a small circle on the pivot above, this means an outlier

# ---
#  º  outlier
#  |
# --- cuantil 75%
# --- cuantil 50%
# --- cuantil 25%
#  |
# ---
